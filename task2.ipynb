# %% [markdown]
# <a href="https://www.kaggle.com/code/ummehabiba12moushi/notebooke057a0d467?scriptVersionId=282904784" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !pip install tensorflow
# !pip install matplotlib
# !pip install scikit-learn
# !pip install scipy
# !pip install efficientnet
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.3)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.1.0,>=1.26.0->tensorflow) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.9/319.9 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.0
#     Uninstalling protobuf-6.33.0:
#       Successfully uninstalled protobuf-6.33.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-cloud-translate 3.12.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.29.5 which is incompatible.
# ray 2.51.1 requires click!=8.3.0,>=7.0, but you have click 8.3.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# Successfully installed protobuf-5.29.5
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->matplotlib) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->matplotlib) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->matplotlib) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->matplotlib) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->matplotlib) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->matplotlib) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.20->matplotlib) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.20->matplotlib) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.20->matplotlib) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.20->matplotlib) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.20->matplotlib) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.20->matplotlib) (2024.2.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17.3->scikit-learn) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17.3->scikit-learn) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17.3->scikit-learn) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17.3->scikit-learn) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17.3->scikit-learn) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17.3->scikit-learn) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17.3->scikit-learn) (2024.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scipy) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.5,>=1.23.5->scipy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.5,>=1.23.5->scipy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.5,>=1.23.5->scipy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.5,>=1.23.5->scipy) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.5,>=1.23.5->scipy) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.5,>=1.23.5->scipy) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.5,>=1.23.5->scipy) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.5,>=1.23.5->scipy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.5,>=1.23.5->scipy) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.5,>=1.23.5->scipy) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.5,>=1.23.5->scipy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.5,>=1.23.5->scipy) (2024.2.0)
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from efficientnet)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from efficientnet) (0.25.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.14.0)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->efficientnet) (0.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.9.1->keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.9.1->keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.9.1->keras-applications<=1.0.8,>=1.0.7->efficientnet) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.9.1->keras-applications<=1.0.8,>=1.0.7->efficientnet) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.9.1->keras-applications<=1.0.8,>=1.0.7->efficientnet) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.9.1->keras-applications<=1.0.8,>=1.0.7->efficientnet) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.9.1->keras-applications<=1.0.8,>=1.0.7->efficientnet) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.9.1->keras-applications<=1.0.8,>=1.0.7->efficientnet) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.9.1->keras-applications<=1.0.8,>=1.0.7->efficientnet) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.9.1->keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.9.1->keras-applications<=1.0.8,>=1.0.7->efficientnet) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.9.1->keras-applications<=1.0.8,>=1.0.7->efficientnet) (2024.2.0)
# Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: keras-applications, efficientnet
# Successfully installed efficientnet-1.1.1 keras-applications-1.0.8

# %%
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# --- 1. CONFIGURATION ---
DATASET_DIR = '/kaggle/input/cervical-cancer-largest-dataset-sipakmed'
WORKING_DIR = '/kaggle/working'
TRAIN_DIR = os.path.join(WORKING_DIR, 'train')
VAL_DIR = os.path.join(WORKING_DIR, 'val')
TEST_DIR = os.path.join(WORKING_DIR, 'test')

IMG_SIZE = 224
BATCH_SIZE = 16  # Set to 16 for better convergence on small data
EPOCHS = 100     

# Clean working directory
for dir_path in [TRAIN_DIR, VAL_DIR, TEST_DIR]:
    if os.path.exists(dir_path):
        shutil.rmtree(dir_path)
    os.makedirs(dir_path)

# --- 2. DATA PREPARATION ---
print("--- Organizing Dataset ---")
class_names = [d for d in os.listdir(DATASET_DIR) if os.path.isdir(os.path.join(DATASET_DIR, d))]
class_names.sort()

for class_name in class_names:
    class_path = os.path.join(DATASET_DIR, class_name, class_name)
    if not os.path.exists(class_path):
        class_path = os.path.join(DATASET_DIR, class_name)
    if not os.path.exists(class_path): continue

    images = [os.path.join(class_path, f) for f in os.listdir(class_path) 
              if f.lower().endswith(('.bmp', '.jpg', '.png'))]
    if len(images) == 0: continue

    train_imgs, temp_imgs = train_test_split(images, test_size=0.3, random_state=42, shuffle=True)
    val_imgs, test_imgs = train_test_split(temp_imgs, test_size=0.5, random_state=42, shuffle=True)

    def copy_images(file_list, destination):
        dest_class_dir = os.path.join(destination, class_name)
        os.makedirs(dest_class_dir, exist_ok=True)
        for img in file_list:
            shutil.copy(img, os.path.join(dest_class_dir, os.path.basename(img)))

    copy_images(train_imgs, TRAIN_DIR)
    copy_images(val_imgs, VAL_DIR)
    copy_images(test_imgs, TEST_DIR)

# --- 3. DATA AUGMENTATION ---
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR, target_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE, class_mode='categorical'
)
val_generator = val_test_datagen.flow_from_directory(
    VAL_DIR, target_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE, class_mode='categorical'
)
test_generator = val_test_datagen.flow_from_directory(
    TEST_DIR, target_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)

NUM_CLASSES = len(class_names)

# --- 4. ROBUST CUSTOM CNN MODEL (Your Requested Block) ---
def build_robust_cnn():
    model = Sequential()
    
    # 1. Input Layer (Fixes the Red Warning)
    model.add(Input(shape=(IMG_SIZE, IMG_SIZE, 3)))
    
    # 2. Block 1
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', kernel_initializer='he_uniform'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    # 3. Block 2
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    
    # 4. Block 3
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))
    
    # 5. Classification Head
    model.add(GlobalAveragePooling2D()) 
    
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5)) 
    
    model.add(Dense(NUM_CLASSES, activation='softmax'))
    
    # 6. Compilation (Using SGD to fix 12% accuracy issue)
    opt = SGD(learning_rate=0.01, momentum=0.9)
    
    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

model = build_robust_cnn()
model.summary()

# --- 5. TRAINING ---
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=15, 
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5, 
    patience=5, 
    min_lr=1e-7, 
    verbose=1
)

print("\n--- Starting Training ---")
history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=val_generator,
    # IMPORTANT: class_weight REMOVED to solve the 12% accuracy bug
    callbacks=[early_stop, reduce_lr]
)

# --- 6. PLOTTING ---
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.show()

plot_history(history)

# --- 7. EVALUATION ---
print("\n--- Final Evaluation ---")
y_pred_probs = model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_generator.classes
target_names = list(test_generator.class_indices.keys())

print(classification_report(y_true, y_pred, target_names=target_names))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix')
plt.ylabel('True Class')
plt.xlabel('Predicted Class')
plt.show()

# Per-Class Accuracy
per_class_accuracy = cm.diagonal() / cm.sum(axis=1)
print("\n=== Per-Class Accuracy ===")
for i, acc in enumerate(per_class_accuracy):
    print(f"{target_names[i]}: {acc * 100:.2f}%")

plt.figure(figsize=(10, 6))
barplot = sns.barplot(x=target_names, y=per_class_accuracy * 100, palette="viridis")
plt.title("Per-Class Accuracy")
plt.ylabel("Accuracy (%)")
plt.xticks(rotation=45)
plt.ylim(0, 110)
for i, v in enumerate(per_class_accuracy * 100):
    barplot.text(i, v + 2, f"{v:.1f}%", ha='center', va='bottom', fontweight='bold')
plt.show()
# Out:
# 2025-11-30 15:52:01.507330: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764517921.766587      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764517921.840664      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# --- Organizing Dataset ---
# Found 674 images belonging to 5 classes.
# Found 145 images belonging to 5 classes.
# Found 147 images belonging to 5 classes.
# 2025-11-30 15:54:24.717413: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,685 (436.27 KB)
#  Trainable params: 111,045 (433.77 KB)
#  Non-trainable params: 640 (2.50 KB)
# --- Starting Training ---
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.3221 - loss: 1.8868 - val_accuracy: 0.1310 - val_loss: 12.1490 - learning_rate: 0.0100
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.3864 - loss: 1.6911 - val_accuracy: 0.2414 - val_loss: 3.5515 - learning_rate: 0.0100
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.4189 - loss: 1.5905 - val_accuracy: 0.3517 - val_loss: 1.7080 - learning_rate: 0.0100
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - accuracy: 0.4761 - loss: 1.5614 - val_accuracy: 0.4000 - val_loss: 2.3672 - learning_rate: 0.0100
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.3930 - loss: 1.6043 - val_accuracy: 0.2828 - val_loss: 6.2335 - learning_rate: 0.0100
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.4280 - loss: 1.4806 - val_accuracy: 0.2828 - val_loss: 14.6537 - learning_rate: 0.0100
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.4886 - loss: 1.3654 - val_accuracy: 0.2828 - val_loss: 12.9053 - learning_rate: 0.0100
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4638 - loss: 1.3484
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.4642 - loss: 1.3488 - val_accuracy: 0.3862 - val_loss: 4.8269 - learning_rate: 0.0100
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.5230 - loss: 1.2404 - val_accuracy: 0.2276 - val_loss: 8.7505 - learning_rate: 0.0050
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.4721 - loss: 1.3267 - val_accuracy: 0.3172 - val_loss: 7.7780 - learning_rate: 0.0050
# Epoch 11/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.5543 - loss: 1.2086 - val_accuracy: 0.2276 - val_loss: 9.0139 - learning_rate: 0.0050
# Epoch 12/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.5737 - loss: 1.1000 - val_accuracy: 0.2759 - val_loss: 7.9265 - learning_rate: 0.0050
# Epoch 13/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6090 - loss: 1.0100
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.6088 - loss: 1.0107 - val_accuracy: 0.4138 - val_loss: 4.5775 - learning_rate: 0.0050
# Epoch 14/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.6059 - loss: 1.0304 - val_accuracy: 0.4621 - val_loss: 2.5425 - learning_rate: 0.0025
# Epoch 15/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.5764 - loss: 1.1057 - val_accuracy: 0.4207 - val_loss: 2.3591 - learning_rate: 0.0025
# Epoch 16/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.5945 - loss: 1.0612 - val_accuracy: 0.3034 - val_loss: 2.5662 - learning_rate: 0.0025
# Epoch 17/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.6128 - loss: 0.9971 - val_accuracy: 0.5448 - val_loss: 1.3993 - learning_rate: 0.0025
# Epoch 18/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.6123 - loss: 1.0516 - val_accuracy: 0.5379 - val_loss: 1.1086 - learning_rate: 0.0025
# Epoch 19/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.6310 - loss: 0.9591 - val_accuracy: 0.5379 - val_loss: 1.2260 - learning_rate: 0.0025
# Epoch 20/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.6641 - loss: 0.9388 - val_accuracy: 0.5655 - val_loss: 1.0820 - learning_rate: 0.0025
# Epoch 21/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.6149 - loss: 0.9765 - val_accuracy: 0.4828 - val_loss: 1.3130 - learning_rate: 0.0025
# Epoch 22/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.6081 - loss: 1.0327 - val_accuracy: 0.5655 - val_loss: 1.0715 - learning_rate: 0.0025
# Epoch 23/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.6768 - loss: 0.9045 - val_accuracy: 0.6069 - val_loss: 0.9449 - learning_rate: 0.0025
# Epoch 24/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.6174 - loss: 0.9390 - val_accuracy: 0.6483 - val_loss: 0.9114 - learning_rate: 0.0025
# Epoch 25/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.6330 - loss: 0.8886 - val_accuracy: 0.5724 - val_loss: 0.9103 - learning_rate: 0.0025
# Epoch 26/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.6598 - loss: 0.9505 - val_accuracy: 0.7103 - val_loss: 0.7873 - learning_rate: 0.0025
# Epoch 27/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.6905 - loss: 0.8622 - val_accuracy: 0.5379 - val_loss: 1.0519 - learning_rate: 0.0025
# Epoch 28/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.6776 - loss: 0.8604 - val_accuracy: 0.7448 - val_loss: 0.7533 - learning_rate: 0.0025
# Epoch 29/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.6654 - loss: 0.9053 - val_accuracy: 0.6621 - val_loss: 0.8420 - learning_rate: 0.0025
# Epoch 30/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.7102 - loss: 0.8003 - val_accuracy: 0.6483 - val_loss: 0.9306 - learning_rate: 0.0025
# Epoch 31/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.6628 - loss: 0.9387 - val_accuracy: 0.5103 - val_loss: 1.4602 - learning_rate: 0.0025
# Epoch 32/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.6856 - loss: 0.8305 - val_accuracy: 0.6897 - val_loss: 0.8859 - learning_rate: 0.0025
# Epoch 33/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7048 - loss: 0.8071
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.7045 - loss: 0.8078 - val_accuracy: 0.5034 - val_loss: 1.5213 - learning_rate: 0.0025
# Epoch 34/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.6783 - loss: 0.8183 - val_accuracy: 0.6897 - val_loss: 0.7441 - learning_rate: 0.0012
# Epoch 35/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.6770 - loss: 0.8318 - val_accuracy: 0.6966 - val_loss: 0.8210 - learning_rate: 0.0012
# Epoch 36/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.7007 - loss: 0.8129 - val_accuracy: 0.7448 - val_loss: 0.6857 - learning_rate: 0.0012
# Epoch 37/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.7021 - loss: 0.8114 - val_accuracy: 0.6483 - val_loss: 0.8554 - learning_rate: 0.0012
# Epoch 38/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - accuracy: 0.6797 - loss: 0.8231 - val_accuracy: 0.7310 - val_loss: 0.7302 - learning_rate: 0.0012
# Epoch 39/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.6733 - loss: 0.8267 - val_accuracy: 0.6690 - val_loss: 0.8517 - learning_rate: 0.0012
# Epoch 40/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.6859 - loss: 0.8329 - val_accuracy: 0.6414 - val_loss: 0.9457 - learning_rate: 0.0012
# Epoch 41/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7240 - loss: 0.7505
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.7237 - loss: 0.7514 - val_accuracy: 0.6276 - val_loss: 0.9607 - learning_rate: 0.0012
# Epoch 42/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.7428 - loss: 0.7591 - val_accuracy: 0.6828 - val_loss: 0.7641 - learning_rate: 6.2500e-04
# Epoch 43/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.7322 - loss: 0.7222 - val_accuracy: 0.7586 - val_loss: 0.6834 - learning_rate: 6.2500e-04
# Epoch 44/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.7215 - loss: 0.7744 - val_accuracy: 0.6897 - val_loss: 0.8319 - learning_rate: 6.2500e-04
# Epoch 45/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.7173 - loss: 0.7544 - val_accuracy: 0.6621 - val_loss: 0.8293 - learning_rate: 6.2500e-04
# Epoch 46/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.7181 - loss: 0.7247 - val_accuracy: 0.6138 - val_loss: 0.9800 - learning_rate: 6.2500e-04
# Epoch 47/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.7102 - loss: 0.7425 - val_accuracy: 0.6897 - val_loss: 0.7708 - learning_rate: 6.2500e-04
# Epoch 48/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7366 - loss: 0.7483
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.7365 - loss: 0.7483 - val_accuracy: 0.6897 - val_loss: 0.8094 - learning_rate: 6.2500e-04
# Epoch 49/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - accuracy: 0.7263 - loss: 0.7113 - val_accuracy: 0.7172 - val_loss: 0.7234 - learning_rate: 3.1250e-04
# Epoch 50/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.7104 - loss: 0.7442 - val_accuracy: 0.6897 - val_loss: 0.7880 - learning_rate: 3.1250e-04
# Epoch 51/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.6902 - loss: 0.8052 - val_accuracy: 0.5931 - val_loss: 1.0844 - learning_rate: 3.1250e-04
# Epoch 52/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.7170 - loss: 0.7724 - val_accuracy: 0.4483 - val_loss: 1.6517 - learning_rate: 3.1250e-04
# Epoch 53/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7329 - loss: 0.7276
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.7328 - loss: 0.7272 - val_accuracy: 0.7448 - val_loss: 0.7480 - learning_rate: 3.1250e-04
# Epoch 54/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.7219 - loss: 0.8185 - val_accuracy: 0.7172 - val_loss: 0.6693 - learning_rate: 1.5625e-04
# Epoch 55/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.7196 - loss: 0.7353 - val_accuracy: 0.7517 - val_loss: 0.6577 - learning_rate: 1.5625e-04
# Epoch 56/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.7449 - loss: 0.7052 - val_accuracy: 0.7241 - val_loss: 0.6759 - learning_rate: 1.5625e-04
# Epoch 57/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.7456 - loss: 0.7450 - val_accuracy: 0.6897 - val_loss: 0.7336 - learning_rate: 1.5625e-04
# Epoch 58/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.7509 - loss: 0.7103 - val_accuracy: 0.7034 - val_loss: 0.6907 - learning_rate: 1.5625e-04
# Epoch 59/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.7582 - loss: 0.7170 - val_accuracy: 0.7103 - val_loss: 0.7086 - learning_rate: 1.5625e-04
# Epoch 60/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7255 - loss: 0.7702
# Epoch 60: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.7257 - loss: 0.7693 - val_accuracy: 0.6759 - val_loss: 0.7828 - learning_rate: 1.5625e-04
# Epoch 61/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.7287 - loss: 0.6942 - val_accuracy: 0.6690 - val_loss: 0.7851 - learning_rate: 7.8125e-05
# Epoch 62/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.7625 - loss: 0.6801 - val_accuracy: 0.6759 - val_loss: 0.8146 - learning_rate: 7.8125e-05
# Epoch 63/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.7452 - loss: 0.7338 - val_accuracy: 0.6759 - val_loss: 0.8097 - learning_rate: 7.8125e-05
# Epoch 64/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.7262 - loss: 0.7677 - val_accuracy: 0.7034 - val_loss: 0.7343 - learning_rate: 7.8125e-05
# Epoch 65/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6969 - loss: 0.7525
# Epoch 65: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.6973 - loss: 0.7528 - val_accuracy: 0.6828 - val_loss: 0.7615 - learning_rate: 7.8125e-05
# Epoch 66/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.7458 - loss: 0.6873 - val_accuracy: 0.6897 - val_loss: 0.7547 - learning_rate: 3.9062e-05
# Epoch 67/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.7476 - loss: 0.7412 - val_accuracy: 0.7103 - val_loss: 0.7346 - learning_rate: 3.9062e-05
# Epoch 68/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.7443 - loss: 0.7328 - val_accuracy: 0.6966 - val_loss: 0.7377 - learning_rate: 3.9062e-05
# Epoch 69/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - accuracy: 0.7330 - loss: 0.7129 - val_accuracy: 0.7103 - val_loss: 0.7224 - learning_rate: 3.9062e-05
# Epoch 70/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7280 - loss: 0.7160
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.7282 - loss: 0.7154 - val_accuracy: 0.7103 - val_loss: 0.6932 - learning_rate: 3.9062e-05
# --- Final Evaluation ---
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step
#                              precision    recall  f1-score   support
#
#             im_Dyskeratotic       0.73      0.71      0.72        34
#             im_Koilocytotic       0.69      0.67      0.68        36
#              im_Metaplastic       0.85      0.85      0.85        41
#                im_Parabasal       0.68      0.88      0.77        17
# im_Superficial-Intermediate       0.94      0.79      0.86        19
#
#                    accuracy                           0.77       147
#                   macro avg       0.78      0.78      0.77       147
#                weighted avg       0.77      0.77      0.77       147
# === Per-Class Accuracy ===
# im_Dyskeratotic: 70.59%
# im_Koilocytotic: 66.67%
# im_Metaplastic: 85.37%
# im_Parabasal: 88.24%
# im_Superficial-Intermediate: 78.95%
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
